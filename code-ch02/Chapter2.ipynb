# %%
############## PLEASE RUN THIS CELL FIRST! ###################

# import everything and define a test runner function
from importlib import reload
from helper import run
import ecc
import helper

from ecc import Point

# %%
from ecc import Point
p1 = Point(-1, -1, 5, 7)
p2 = Point(-1, -2, 5, 7) #this point is actually not on the curve, should raise a value error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_8365/626945755.py in <module>
#       1 from ecc import Point
#       2 p1 = Point(-1, -1, 5, 7)
# ----> 3 p2 = Point(-1, -2, 5, 7) #this point is actually not on the curve, should raise a value error
#
# /media/henning/Volume/Programming/Bitcoin/programmingbitcoin/code-ch02/ecc.py in __init__(self, x, y, a, b)
#     129         if not (x is None) and not (y is None):
#     130             if self.y**2 != self.x**3 + a * x + b:  # <1>
# --> 131                 raise ValueError('({}, {}) is not on the curve'.format(x, y))
#     132
#     133     def __eq__(self, other):  # <2>
#
# ValueError: (-1, -2) is not on the curve

# %% [markdown]
# ### Exercise 1
#
# Determine which of these points are on the curve \\(y^{2}\\)=\\(x^{3}\\)+5x+7:
#
# (2,4), (-1,-1), (18,77), (5,7)

# %%
# Exercise 1

# (2,4), (-1,-1), (18,77), (5,7)
# equation in python is: y**2 == x**3 + 5*x + 7

# %% [markdown]
# ### Exercise 2
#
# Write the `__ne__` method for `Point`.
#
# #### Make [this test](/edit/code-ch02/ecc.py) pass: `ecc.py:PointTest:test_ne`

# %%
# Exercise 2

reload(ecc)
run(ecc.PointTest("test_ne"))
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# OK

# %% [markdown]
# ### Exercise 4
#
# For the curve \\(y^{2}\\)=\\(x^{3}\\)+5x+7, what is (2,5) + (-1,-1)?

# %%
# Exercise 4

from ecc import Point

a = 5
b = 7
x1, y1 = 2, 5
x2, y2 = -1, -1

# (x1,y1) + (x2,y2)

# %% [markdown]
# ### Exercise 5
#
# Write the `__add__` method where \\(x_{1}\\)≠\\(x_{2}\\)
#
# #### Make [this test](/edit/code-ch02/ecc.py) pass: `ecc.py:PointTest:test_add1`

# %%
# Exercise 5

reload(ecc)
run(ecc.PointTest("test_add1"))
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# OK

# %% [markdown]
# ### Exercise 6
#
# For the curve \\(y^{2}\\)=\\(x^{3}\\)+5x+7, what is (-1,-1) + (-1,-1)?

# %%
# Exercise 6

from ecc import Point

a = 5
b = 7
x1, y1 = -1, -1
# (-1,-1) + (-1,-1)

# %% [markdown]
# ### Exercise 7
#
# Write the `__add__` method when \\(P_{1}\\)=\\(P_{2}\\).
#
# #### Make [this test](/edit/code-ch02/ecc.py) pass: `ecc.py:PointTest:test_add2`

# %%
# Exercise 7

reload(ecc)
run(ecc.PointTest("test_add2"))
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# OK
